# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Data reading**

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/credit_card_pw_hindi/main/creditCardFraud_28011964_120214.csv")

# %% [markdown]
# -- Dataset Information
#
#
# * LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# * SEX: Gender (1=male, 2=female)
# * EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# MARRIAGE: Marital status (1=married, 2=single, 3=others)
# * AGE: Age in years
# * PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, ... 8=payment delay for eight months, 9=payment delay for nine months and above)
# * PAY_2: Repayment status in August, 2005 (scale same as above)
# * PAY_3: Repayment status in July, 2005 (scale same as above)
# * PAY_4: Repayment status in June, 2005 (scale same as above)
# * PAY_5: Repayment status in May, 2005 (scale same as above)
# * PAY_6: Repayment status in April, 2005 (scale same as above)
# * BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# * BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# * BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# * BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# * BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# * BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# * PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# * PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# * PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# * PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# * PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# * PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# * default.payment.next.month: Default payment (1=yes, 0=no)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0      9000       689       679                           0
# 1      1000      1000       800                           0
# 2     20239     13750     13770                           0
# 3       581      1687      1542                           0
# 4      1000      1000      1000                           0
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# !pip install pandas-profiling
from pandas_profiling import ProfileReport
# Out:
# Requirement already satisfied: pandas-profiling in /usr/local/lib/python3.10/dist-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.10/dist-packages (from pandas-profiling) (4.5.1)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.11.2)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.5.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (3.7.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.10.12)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (0.7.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (4.66.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (0.14.0)
# Requirement already satisfied: typeguard<3,>=2.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.9.2)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.8.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.4.0)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling->pandas-profiling) (2023.3.post1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.3.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas-profiling) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
#  13  BILL_AMT3                   1001 non-null   int64
#  14  BILL_AMT4                   1001 non-null   int64
#  15  BILL_AMT5                   1001 non-null   int64
#  16  BILL_AMT6                   1001 non-null   int64
#  17  PAY_AMT1                    1001 non-null   int64
#  18  PAY_AMT2                    1001 non-null   int64
#  19  PAY_AMT3                    1001 non-null   int64
#  20  PAY_AMT4                    1001 non-null   int64
#  21  PAY_AMT5                    1001 non-null   int64
#  22  PAY_AMT6                    1001 non-null   int64
#  23  default payment next month  1001 non-null   int64
# dtypes: int64(24)
# memory usage: 187.8 KB

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
# profile.to_file("your_report.html")

# %%
df['default payment next month'].value_counts()
# Out:
# 0    787
# 1    214
# Name: default payment next month, dtype: int64

# %%
# For seeing analysis in html form w/o downloading page
# profile.to_notebook_iframe()

# %%
x = df.drop(labels=['default payment next month'],axis = 1)

# %%
x
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0         0  ...      35835      20940      19146      19131      2000
# 1         0  ...      57608      19394      19619      20024      2500
# 2         0  ...     445007     542653     483003     473944     55000
# 3         0  ...        601        221       -159        567       380
# 4         0  ...      12108      12211      11793       3719      3329
# ...     ...  ...        ...        ...        ...        ...       ...
# 996      -1  ...      67782      -2618      95748     101299      3320
# 997       0  ...       8441      97041     103541       3632      5000
# 998      -1  ...       1114        657       1332        780         0
# 999      -2  ...          0          0          0          0         0
# 1000     -2  ...       3420       2527          0          0      9664
#
#       PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0        36681     10000      9000       689       679
# 1         1815       657      1000      1000       800
# 2        40000     38000     20239     13750     13770
# 3          601         0       581      1687      1542
# 4            0       432      1000      1000      1000
# ...        ...       ...       ...       ...       ...
# 996       5000         0    100000      7186         0
# 997       2000     89000      6500        91      1504
# 998       2806      2256      2274       780         0
# 999          0         0         0         0         0
# 1000      3420      2612         0         0         0
#
# [1001 rows x 23 columns]

# %%
y = df['default payment next month']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25,random_state=50)

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(x_train)

# %%
X_test_scaled = scaler.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()

# %%
from sklearn.model_selection import GridSearchCV
params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
clf = GridSearchCV(clf,param_grid=params_NB,cv=2,verbose=3)

# %%
clf.fit(X_train_scaled, y_train)
# Out:
# Fitting 2 folds for each of 100 candidates, totalling 200 fits
# [CV 1/2] END .................var_smoothing=1.0;, score=0.776 total time=   0.0s
# [CV 2/2] END .................var_smoothing=1.0;, score=0.757 total time=   0.0s
# [CV 1/2] END ..var_smoothing=0.8111308307896871;, score=0.765 total time=   0.0s
# [CV 2/2] END ..var_smoothing=0.8111308307896871;, score=0.731 total time=   0.0s
# [CV 1/2] END ...var_smoothing=0.657933224657568;, score=0.757 total time=   0.0s
# [CV 2/2] END ...var_smoothing=0.657933224657568;, score=0.696 total time=   0.0s
# [CV 1/2] END ...var_smoothing=0.533669923120631;, score=0.747 total time=   0.0s
# [CV 2/2] END ...var_smoothing=0.533669923120631;, score=0.661 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.43287612810830584;, score=0.757 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.43287612810830584;, score=0.621 total time=   0.0s
# [CV 1/2] END ..var_smoothing=0.3511191734215131;, score=0.760 total time=   0.0s
# [CV 2/2] END ..var_smoothing=0.3511191734215131;, score=0.573 total time=   0.0s
# [CV 1/2] END ..var_smoothing=0.2848035868435802;, score=0.757 total time=   0.0s
# [CV 2/2] END ..var_smoothing=0.2848035868435802;, score=0.547 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.23101297000831597;, score=0.757 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.23101297000831597;, score=0.517 total time=   0.0s
# [CV 1/2] END ..var_smoothing=0.1873817422860384;, score=0.763 total time=   0.0s
# [CV 2/2] END ..var_smoothing=0.1873817422860384;, score=0.483 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.15199110829529336;, score=0.752 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.15199110829529336;, score=0.467 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.12328467394420659;, score=0.744 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.12328467394420659;, score=0.464 total time=   0.0s
# [CV 1/2] END .................var_smoothing=0.1;, score=0.731 total time=   0.0s
# [CV 2/2] END .................var_smoothing=0.1;, score=0.459 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.08111308307896872;, score=0.733 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.08111308307896872;, score=0.459 total time=   0.0s
# [CV 1/2] END ..var_smoothing=0.0657933224657568;, score=0.741 total time=   0.0s
# [CV 2/2] END ..var_smoothing=0.0657933224657568;, score=0.461 total time=   0.0s
# [CV 1/2] END ..var_smoothing=0.0533669923120631;, score=0.741 total time=   0.0s
# [CV 2/2] END ..var_smoothing=0.0533669923120631;, score=0.459 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.04328761281083057;, score=0.739 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.04328761281083057;, score=0.459 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.03511191734215131;, score=0.741 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.03511191734215131;, score=0.461 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.02848035868435802;, score=0.739 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.02848035868435802;, score=0.459 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.02310129700083159;, score=0.741 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.02310129700083159;, score=0.456 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.01873817422860384;, score=0.739 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.01873817422860384;, score=0.456 total time=   0.0s
# [CV 1/2] END .var_smoothing=0.01519911082952933;, score=0.739 total time=   0.0s
# [CV 2/2] END .var_smoothing=0.01519911082952933;, score=0.456 total time=   0.0s
# [CV 1/2] END var_smoothing=0.012328467394420659;, score=0.739 total time=   0.0s
# [CV 2/2] END var_smoothing=0.012328467394420659;, score=0.459 total time=   0.0s
# [CV 1/2] END ................var_smoothing=0.01;, score=0.741 total time=   0.0s
# [CV 2/2] END ................var_smoothing=0.01;, score=0.459 total time=   0.0s
# [CV 1/2] END var_smoothing=0.008111308307896872;, score=0.739 total time=   0.0s
# [CV 2/2] END var_smoothing=0.008111308307896872;, score=0.456 total time=   0.0s
# [CV 1/2] END var_smoothing=0.006579332246575682;, score=0.739 total time=   0.0s
# [CV 2/2] END var_smoothing=0.006579332246575682;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.005336699231206307;, score=0.739 total time=   0.0s
# [CV 2/2] END var_smoothing=0.005336699231206307;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.004328761281083057;, score=0.739 total time=   0.0s
# [CV 2/2] END var_smoothing=0.004328761281083057;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.003511191734215131;, score=0.739 total time=   0.0s
# [CV 2/2] END var_smoothing=0.003511191734215131;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.002848035868435802;, score=0.739 total time=   0.0s
# [CV 2/2] END var_smoothing=0.002848035868435802;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0023101297000831605;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0023101297000831605;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.001873817422860383;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.001873817422860383;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0015199110829529332;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0015199110829529332;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0012328467394420659;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0012328467394420659;, score=0.453 total time=   0.0s
# [CV 1/2] END ...............var_smoothing=0.001;, score=0.736 total time=   0.0s
# [CV 2/2] END ...............var_smoothing=0.001;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0008111308307896872;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0008111308307896872;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0006579332246575676;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0006579332246575676;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0005336699231206307;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0005336699231206307;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0004328761281083057;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0004328761281083057;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0003511191734215131;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0003511191734215131;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0002848035868435802;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0002848035868435802;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0002310129700083158;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0002310129700083158;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0001873817422860383;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0001873817422860383;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0001519911082952933;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0001519911082952933;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=0.0001232846739442066;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=0.0001232846739442066;, score=0.453 total time=   0.0s
# [CV 1/2] END ..............var_smoothing=0.0001;, score=0.736 total time=   0.0s
# [CV 2/2] END ..............var_smoothing=0.0001;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=8.111308307896872e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=8.111308307896872e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=6.579332246575683e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=6.579332246575683e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=5.3366992312063123e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=5.3366992312063123e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=4.328761281083062e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=4.328761281083062e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=3.511191734215127e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=3.511191734215127e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.848035868435799e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.848035868435799e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.310129700083158e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.310129700083158e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.873817422860383e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.873817422860383e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.5199110829529332e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.5199110829529332e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.2328467394420658e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.2328467394420658e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END ...............var_smoothing=1e-05;, score=0.736 total time=   0.0s
# [CV 2/2] END ...............var_smoothing=1e-05;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=8.111308307896873e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=8.111308307896873e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=6.579332246575683e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=6.579332246575683e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=5.336699231206313e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=5.336699231206313e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=4.328761281083053e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=4.328761281083053e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=3.5111917342151275e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=3.5111917342151275e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.848035868435799e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.848035868435799e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.310129700083158e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.310129700083158e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.873817422860383e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.873817422860383e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.519911082952933e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.519911082952933e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.232846739442066e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.232846739442066e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END ...............var_smoothing=1e-06;, score=0.736 total time=   0.0s
# [CV 2/2] END ...............var_smoothing=1e-06;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=8.111308307896872e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=8.111308307896872e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=6.579332246575682e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=6.579332246575682e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=5.336699231206313e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=5.336699231206313e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=4.3287612810830526e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=4.3287612810830526e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=3.5111917342151277e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=3.5111917342151277e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.848035868435799e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.848035868435799e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.310129700083158e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.310129700083158e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.873817422860383e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.873817422860383e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.519911082952933e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.519911082952933e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.232846739442066e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.232846739442066e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END ...............var_smoothing=1e-07;, score=0.736 total time=   0.0s
# [CV 2/2] END ...............var_smoothing=1e-07;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=8.111308307896873e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=8.111308307896873e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=6.579332246575682e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=6.579332246575682e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=5.336699231206302e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=5.336699231206302e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=4.3287612810830526e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=4.3287612810830526e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=3.5111917342151277e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=3.5111917342151277e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.848035868435799e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.848035868435799e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.310129700083158e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.310129700083158e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.873817422860383e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.873817422860383e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.519911082952933e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.519911082952933e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.232846739442066e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.232846739442066e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END ...............var_smoothing=1e-08;, score=0.736 total time=   0.0s
# [CV 2/2] END ...............var_smoothing=1e-08;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=8.111308307896856e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=8.111308307896856e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=6.579332246575682e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=6.579332246575682e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=5.336699231206302e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=5.336699231206302e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=4.328761281083061e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=4.328761281083061e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=3.5111917342151273e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=3.5111917342151273e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.848035868435805e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.848035868435805e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=2.310129700083158e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=2.310129700083158e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.873817422860387e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.873817422860387e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.519911082952933e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.519911082952933e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END var_smoothing=1.2328467394420635e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END var_smoothing=1.2328467394420635e-09;, score=0.453 total time=   0.0s
# [CV 1/2] END ...............var_smoothing=1e-09;, score=0.736 total time=   0.0s
# [CV 2/2] END ...............var_smoothing=1e-09;, score=0.453 total time=   0.0s
# GridSearchCV(cv=2, estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.84803587e-02, 2.31...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              verbose=3)

# %%
clf.best_params_
# Out:
# {'var_smoothing': 1.0}

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
clf = GaussianNB(var_smoothing = 0.8111308307896871)
clf.fit(X_train_scaled, y_train)
y_pred = clf.predict(X_test_scaled)
accuracy_score(y_test,y_pred)
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.84      0.93      0.88       201\n           1       0.52      0.30      0.38        50\n\n    accuracy                           0.80       251\n   macro avg       0.68      0.62      0.63       251\nweighted avg       0.78      0.80      0.78       251\n'

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
xgb.fit(X_train_scaled,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
param_grid_xgboost = { "n_estimators": [50,100, 130],
                        "max_depth": range(3,11,1),
                      "random_state":[0,50,100]
                     }

# Creating an object of the Grid Search class
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid_xgboost,verbose=3,cv=5,n_jobs=-1)

# %%
grid.fit(X_train_scaled,y_train)
y_pred2 = grid.predict(X_test_scaled)
print(accuracy_score(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# 0.7768924302788844
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       201
#            1       0.43      0.38      0.40        50
#
#     accuracy                           0.78       251
#    macro avg       0.64      0.63      0.63       251
# weighted avg       0.77      0.78      0.77       251

# %%
grid.best_params_
# Out:
# {'max_depth': 4, 'n_estimators': 100, 'random_state': 0}

# %%
grid = XGBClassifier(max_depth = 4, n_estimators = 100, random_state = 0)

# %%
grid.fit(X_train_scaled, y_train)
y_pred1 = grid.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.7768924302788844

# %% [markdown]
# -- So we can see that Gaussian Naive Bayes is giving us 80% accuracy. So we will use that for our predictions

# %%
import pickle
pickle.dump(grid,open('xgboost','wb'))

# %%
# Out:
#   File "<ipython-input-91-f188d5ac1197>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax
